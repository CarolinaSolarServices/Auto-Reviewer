# %%
import pandas as pd
import requests

# %%
df = pd.read_csv("SiteAddressData.csv")
df = df[['Site Name', 'Address', 'City', 'State']]
df
# Out:
#          Site Name                    Address         City State
# 0             1634  445 W Bobo Newsom Highway   Hartsville    SC
# 1            ART 1     1947 N Fayetteville St     Asheboro    NC
# 2            ART 3        187 High House Road         Cary    NC
# 3            ART 4           149 Campus Drive    Warrenton    NC
# 4           ASPP 2              17900 Dana Rd   Laurinburg    NC
# ..             ...                        ...          ...   ...
# 157         Weaver         4265 Lynchburg Hwy    Lynchbrug    SC
# 158  West Newberry     304 Industrial Park Rd     Newberry    SC
# 159     Wingo Park       5670 N Blackstock Rd  Spartanburg    SC
# 160       Woodline           17017 HWY 140 E         Dairy    OR
# 161      Woodsdale          1433 Woodsdale Rd      Roxboro    NC
#
# [162 rows x 4 columns]

# %%
def getGeocoding (base_url, address, API_Key):
    params = {
        "address": address,
        "key": API_Key
    }

    response = requests.get(base_url, params=params)

    lat = None
    lng = None
    if response.status_code == 200:
        res = response.json()
        if res['status'] == 'OK':
            lat = res['results'][0]['geometry']['location']['lat']
            lng = res['results'][0]['geometry']['location']['lng']
            print(f"The latitude and longitude of {address} are {lat} and {lng}.")
        else:
            print(f"Unable to get geocode for {address}. Error: {res['status']}")
    else:
        print(f"Error: Unable to connect to the Geocoding API for {address}")

    return lat, lng

# %%
API_Key = "AIzaSyCvVHQK2JkHP70CBoW1rv3YBnxd7wh9_oQ"
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

latitudes = []
longitudes = []

for index, row in df.iterrows():
    address = f"{row['Address']}, {row['City']}, {row['State']}"
    lat, lng = getGeocoding(base_url, address, API_Key)
    latitudes.append(lat)
    longitudes.append(lng)

df['Latitude'] = latitudes
df['Longitude'] = longitudes
df
# Out:
# The latitude and longitude of 445 W Bobo Newsom Highway, Hartsville, SC are 34.3387023 and -80.0826036.
# The latitude and longitude of 1947 N Fayetteville St, Asheboro, NC are 35.752593 and -79.8063854.
# The latitude and longitude of 187 High House Road, Cary, NC are 35.7832799 and -78.7984122.
# The latitude and longitude of 149 Campus Drive, Warrenton, NC are 36.4324177 and -78.1655282.
# The latitude and longitude of 17900 Dana Rd, Laurinburg, NC are 34.7740494 and -79.46282479999999.
# The latitude and longitude of 627 Hwy 17, Piedmont, SC are 34.6954421 and -82.52947259999999.
# The latitude and longitude of S.Neilson Rd; W. 3rd St, Lind, WA are 46.9659215 and -118.6210891.
# The latitude and longitude of 14841 Agate Rd, Eagle Point, OR are 42.5225614 and -122.8367639.
# The latitude and longitude of 119 Coy Smith Rd. , Albertson, NC are 35.0936415 and -77.8122265.
# The latitude and longitude of 1523 US 221 HWY South, Rutherfordton, NC are 35.3161945 and -81.92886460000001.
# ...

# %%
nan_rows = df[df['Latitude'].isna() | df['Longitude'].isna()]
nan_rows
# Out:
#    Site Name               Address   City State  Latitude  Longitude
# 36     Dairy  977-1099 Mitchell Rd  Dairy    OR       NaN        NaN

# %%
params = {
    "address": "977 Mitchell Rd, Dairy, OR",
    "key": API_Key
}

response = requests.get(base_url, params=params)

lat = None
lng = None
if response.status_code == 200:
    res = response.json()
    if res['status'] == 'OK':
        lat = res['results'][0]['geometry']['location']['lat']
        lng = res['results'][0]['geometry']['location']['lng']
        print(f"The latitude and longitude of {address} are {lat} and {lng}.")
    else:
        print(f"Unable to get geocode for {address}. Error: {res['status']}")
else:
    print(f"Error: Unable to connect to the Geocoding API for {address}")
# Out:
# The latitude and longitude of 1433 Woodsdale Rd, Roxboro, NC are 43.8041334 and -120.5542012.

# %%
df.to_csv(f'geoCoding.csv', index=False)
